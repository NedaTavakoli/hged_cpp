# %%
import numpy as np
import matplotlib.pyplot as plt
import fileinput
from matplotlib.ticker import MaxNLocator
from collections import namedtuple
from math import log
from matplotlib.dates import date2num
import datetime
import pandas as pd
import seaborn as sns
from numpy import loadtxt

# %% [markdown]
# # Chr 22

# %% [markdown]
# # Number of ILP componets while changing alpha (Ed), delta = 1%

# %%
N_components = [216057, 200580, 52333, 14508, 9660, 404]

alpha_1 = [50, 75, 100, 150, 500, 1000]

# %%
plt.scatter(alpha_1, N_components, c ="purple",
            linewidths = 2,
            marker ="^",
            edgecolor ="purple",
            s = 100, label='Number of ILP components')
# plt.plot(alpha_1, N_components, 'b^',  linewidth = 3,label='Number of ILP components')


# # setting x and y axis range
plt.xlim(0,1050)

plt.xticks([100, 500, 1000], fontsize=15)
plt.yticks(fontsize=15)

plt.xlabel(r'$\alpha$', fontsize=30)
plt.ylabel('ILP Components',fontsize=30)
plt.title(r'$\delta =1\%$',fontsize=30)
plt.legend(fontsize=17,loc=1)

plt.savefig('number_ILP_components_per_alpha-chr22_delta1.pdf', bbox_inches="tight")
plt.show()

# %% [markdown]
# # Number of ILP componets while changing alpha (Ed), delta = 3%

# %%
N_components_2 = [207693, 96530, 48077, 13205, 898, 49]

alpha_1 = [50, 75, 100, 150, 500, 1000]

# %%
plt.scatter(alpha_1, N_components_2, c ="lightseagreen",
            linewidths = 2,
            marker ="*",
            edgecolor ="lightseagreen",
            s = 100, label='Number of ILP components')
# plt.plot(alpha_1, N_components, 'b^',  linewidth = 3,label='Number of ILP components')

# # setting x and y axis range
plt.xlim(0,1050)

plt.xticks([100, 500, 1000], fontsize=15)
plt.yticks(fontsize=15)

plt.xlabel(r'$\alpha$', fontsize=30)
plt.ylabel('ILP Components',fontsize=30)
plt.title(r'$\delta =3\%$',fontsize=30)
plt.legend(fontsize=17,loc=1)

plt.savefig('number_ILP_components_per_alpha-chr22_delta3.pdf', bbox_inches="tight")
plt.show()

# %% [markdown]
# # Number of variants per component as we change alpha, delta = 1%

# %%
plt.plot(components_50_1, 'b-',  linewidth = 3,label=r'$\alpha =50$')

plt.xlabel('component', fontsize=30)
plt.ylabel('Size ILP Components',fontsize=30)
plt.title(r'$\delta =1\%$',fontsize=30)
plt.legend(fontsize=17,loc=1)

plt.savefig('size_components_per_alpha-chr22.pdf', bbox_inches="tight")
plt.show()

# %%
df = pd.DataFrame({
    r'$\alpha =50$': reverse_array_1,
})
ax = df.plot.area()

# %%
n = len(components_50_1)
x = np.arange(0,n)

# Sort in ascending order
sorted_array = np.sort(components_50_1)
# Reverse the sorted array
reverse_array = sorted_array[::-1]

plt.plot(x, reverse_array , 'b-',  linewidth = 3,label=r'$\alpha =50$')

plt.xlabel('component', fontsize=30)
plt.ylabel('Size ILP Components',fontsize=30)
plt.title(r'$\delta =1\%$',fontsize=30)
plt.legend(fontsize=17,loc=1)

plt.savefig('[size_components_per_alpha-chr22.pdf', bbox_inches="tight")
plt.show()

# %%
# read from file
components_50_1 = loadtxt("varinats_per_component_50_1.txt", unpack=False)
components_75_1 = loadtxt("varinats_per_component_75_1.txt", unpack=False)
components_100_1 = loadtxt("varinats_per_component_100_1.txt", unpack=False)
components_150_2 = loadtxt("varinats_per_component_150_2.txt", unpack=False)

# %%
# Sort in ascending order
sorted_array_1 = np.sort(components_50_1)
reverse_array_1 = sorted_array[::-1]
n1 = len(components_50_1)
x1 = np.arange(0,n1)

sorted_array_2 = np.sort(components_75_1)
reverse_array_2 = sorted_array[::-1]
n2 = len(components_75_1)
x2 = np.arange(0,n2)

sorted_array_3 = np.sort(components_100_1)
reverse_array_3= sorted_array[::-1]
n3 = len(components_100_1)
x3 = np.arange(0,n3)

sorted_array_4 = np.sort(components_150_2)
reverse_array_4 = sorted_array[::-1]
n4 = len(components_150_2)
x4 = np.arange(0,n4)

fig = plt.figure() 

plt.subplot(2, 2, 1)
plt.ylim(0, 3500)
plt.xlim(0,20000)
plt.scatter(x1,components_50_1 , color = 'black',  linewidth = 1,label=r'$\alpha =50$')
plt.legend(fontsize=10,loc=1)


plt.subplot(2, 2, 2)
plt.ylim(0, 3500)
plt.xlim(0,20000)
plt.scatter(x2,components_75_1 , color = 'aqua',  linewidth = 1,label=r'$\alpha =75$')
plt.legend(fontsize=10,loc=1)

plt.subplot(2, 2, 3)
plt.ylim(0, 3500)
plt.xlim(0,20000)
plt.scatter(x3, components_100_1 , color = 'slateblue',  linewidth = 1,label=r'$\alpha =100$')
plt.legend(fontsize=10,loc=1)


plt.subplot(2, 2, 4)
plt.ylim(0, 3500)
plt.xlim(0,20000)
plt.scatter(x4,components_150_2 , color = 'blue',  linewidth = 1,label=r'$\alpha =150$')
plt.legend(fontsize=10,loc=1)


# Set common labels
fig.text(0.5, 0.02, 'ILP component', ha='center', va='center',fontsize=20)
fig.text(0.03, 0.5, 'Component size', ha='center', va='center', rotation='vertical', fontsize=20)


fig.suptitle(r'$\delta =1\%$',fontsize=20)


plt.savefig('[size_components_per_alpha-chr22.pdf', bbox_inches="tight")
plt.show()

# %%
# read from file
components_50_2 = loadtxt("varinats_per_component_50_2.txt", unpack=False)
components_75_3 = loadtxt("varinats_per_component_75_3.txt", unpack=False)
components_100_3 = loadtxt("varinats_per_component_100_3.txt", unpack=False)
components_150_5 = loadtxt("varinats_per_component_150_5.txt", unpack=False)

# %%
# Sort in ascending order
sorted_array_1 = np.sort(components_50_2)
reverse_array_1 = sorted_array[::-1]
n1 = len(components_50_2)
x1 = np.arange(0,n1)

sorted_array_2 = np.sort(components_75_3)
reverse_array_2 = sorted_array[::-1]
n2 = len(components_75_3)
x2 = np.arange(0,n2)

sorted_array_3 = np.sort(components_100_3)
reverse_array_3= sorted_array[::-1]
n3 = len(components_100_3)
x3 = np.arange(0,n3)

sorted_array_4 = np.sort(components_150_5)
reverse_array_4 = sorted_array[::-1]
n4 = len(components_150_5)
x4 = np.arange(0,n4)

fig = plt.figure() 

plt.subplot(2, 2, 1)
plt.ylim(0, 3500)
plt.xlim(0,20000)
plt.scatter(x1,components_50_2 , color = 'black',  linewidth = 1,label=r'$\alpha =50$')
plt.legend(fontsize=10,loc=1)


plt.subplot(2, 2, 2)
plt.ylim(0, 3500)
plt.xlim(0,20000)
plt.scatter(x2,components_75_3 , color = 'aqua',  linewidth = 1,label=r'$\alpha =75$')
plt.legend(fontsize=10,loc=1)

plt.subplot(2, 2, 3)
plt.ylim(0, 3500)
plt.xlim(0,20000)
plt.scatter(x3, components_100_3 , color = 'slateblue',  linewidth = 1,label=r'$\alpha =100$')
plt.legend(fontsize=10,loc=1)


plt.subplot(2, 2, 4)
plt.ylim(0, 3500)
plt.xlim(0,20000)
plt.scatter(x4,components_150_5 , color = 'blue',  linewidth = 1,label=r'$\alpha =150$')
plt.legend(fontsize=10,loc=1)


# Set common labels
fig.text(0.5, 0.02, 'ILP component', ha='center', va='center',fontsize=20)
fig.text(0.03, 0.5, 'Component size', ha='center', va='center', rotation='vertical', fontsize=20)


fig.suptitle(r'$\delta =3\%$',fontsize=20)


plt.savefig('[size_components_per_alpha-chr22.pdf', bbox_inches="tight")
plt.show()

# %%
# plot something
fig, axs = plt.subplots(3,3, figsize=(15, 8), sharex=True, sharey=True)
for i, ax in enumerate(axs.flat):
    ax.scatter(*np.random.normal(size=(2,200)))
    ax.set_title(f'Title {i}')

# set labels
plt.setp(axs[-1, :], xlabel='x axis label')
plt.setp(axs[:, 0], ylabel='y axis label')
# Out:
# [Text(0, 0.5, 'y axis label'),
#  Text(0, 0.5, 'y axis label'),
#  Text(0, 0.5, 'y axis label')]

# %% [markdown]
# # 1- Variants retained while changing alpha (SNPs), delta = 10%

# %%
# Delta = 10% * alpha

# %%
N_varinats_greedy = [6906,2538,872,695]
N_varinats_LP = [6746,2426,840,674]
N_varinats_ILP_Hap = [3323,956,296,186] # New

alpha = [150, 1000, 5000, 10000]

# %%
data = [N_varinats_greedy,N_varinats_LP,N_varinats_ILP_Hap]

X = np.arange(4)
width = 0.25
plt.bar(X - width/3, data[0], color = 'navy', width = 0.17,label='Greedy')
plt.bar(X + width/3, data[1], color = 'c', width = 0.17,label='LP')
plt.bar(X + width ,data[2], color = 'slateblue', width = 0.17,label='ILP Haplotype Aware') # New

plt.xticks(range(0,4), [150, 1000, 5000, 10000], fontsize=25)
plt.yticks(fontsize=25)

# plt.yscale("log")
# Get the y limits
ymin, ymax = 1,100000000
# Set the y limits making the maximum 5% greater
#plt.ylim(ymin, 0.05 * ymax)


plt.xlabel(r'$\alpha$', fontsize=30)
plt.ylabel('Variants retained',fontsize=30)
plt.title(r'$\delta =10\%$',fontsize=30)
plt.legend(fontsize=17,loc=1)


plt.savefig('[SNP]-nolog-1-chr22.pdf', bbox_inches="tight")
plt.show()

# %%
# https://matplotlib.org/2.0.2/examples/color/named_colors.html

# %% [markdown]
# # 2- Variants retained while changing delta for alpha = 150 (SNPs)

# %%
N_varinats_greedy = [1063618,707279,91913,6906]
N_varinats_LP = [1063618,705111,91316,6746]
N_varinats_ILP_Hap = [1063618,357279,30476,3323] # New
delta = [0, 1, 5, 10]

# %%
# data = [N_varinats_greedy,N_varinats_LP]
data = [N_varinats_greedy,N_varinats_LP,N_varinats_ILP_Hap]


X = np.arange(4)
width = 0.25
plt.bar(X - width/3, data[0], color = 'navy', width = 0.17,label='Greedy')
plt.bar(X + width/3, data[1], color = 'c', width = 0.17,label='LP')
plt.bar(X + width ,data[2], color = 'slateblue', width = 0.17,label='ILP Haplotype Aware') # New

plt.xticks(range(0,4), ['0%', '1%','5%', '10%'], fontsize=25)
plt.yticks(fontsize=25)


#To hide y-axis values
# frame1 = plt.gca()
# frame1.axes.get_yaxis().set_visible(False)

# plt.yscale("log")
# Get the y limits
# ymin, ymax = 1,1500000
# Set the y limits making the maximum 5% greater
# plt.ylim(ymin, 1.05 * ymax)



plt.xlabel(r'$\delta$', fontsize=30)
plt.ylabel('Variants retained',fontsize=30)
plt.title(r'$\alpha =150$',fontsize=30)
#plt.legend()
plt.savefig('[SNP]-nolog-2-chr22.pdf', bbox_inches="tight")
plt.show()

# %%
N_varinats_greedy = [91913,6906]
N_varinats_LP = [91316,6746]
N_varinats_ILP_Hap = [30476,3323] # New
delta = [ 5, 10]

# %%
data = [N_varinats_greedy,N_varinats_LP,N_varinats_ILP_Hap]

X = np.arange(2)
width = 0.25
plt.bar(X - width/3, data[0], color = 'navy', width = 0.17,label='Greedy')
plt.bar(X + width/3, data[1], color = 'c', width = 0.17,label='LP')
plt.bar(X + width ,data[2], color = 'slateblue', width = 0.17,label='ILP Haplotype Aware') # New

plt.xticks(range(0,2), ['5%', '10%'], fontsize=25)
plt.yticks(fontsize=25)

#To hide y-axis values
# frame1 = plt.gca()
# frame1.axes.get_yaxis().set_visible(False)

# plt.yscale("log")
# Get the y limits
# ymin, ymax = 1,8000
# ymin, ymax = 1,100000000
# Set the y limits making the maximum 5% greater
# plt.ylim(ymin, 1.05 * ymax)
# plt.ylim(ymin, ymax)

plt.xlabel(r'$\delta$', fontsize=30)
#plt.ylabel('Variants retained',fontsize=30)
plt.title(r'$\alpha =150$',fontsize=30)
#plt.legend()
plt.savefig('[SNP]-nolog-2-chr22_zoom.pdf', bbox_inches="tight")
plt.show()

# %% [markdown]
# # 3- Variants retained while changing delta for alpha = 5000(SNPs)

# %%
N_varinats_greedy = [1063618,724871,7392,872]
N_varinats_LP = [1063618,721957,7239,840]
N_varinats_ILP_Hap = [1063618,365598,2435,296 ] # New

delta = [0, 1, 5, 10]

# %%
# range_to_normalize = (0, 1)
# Normalized_N_varinats_greedy = normalize(N_varinats_greedy, range_to_normalize[0], range_to_normalize[1])
# Normalized_N_varinats_LP = normalize(N_varinats_LP, range_to_normalize[0], range_to_normalize[1])
# Normalized_N_varinats_ILP_Hap = normalize(N_varinats_ILP_Hap, range_to_normalize[0], range_to_normalize[1])

# %%
data = [N_varinats_greedy,N_varinats_LP,N_varinats_ILP_Hap]
#data = [Normalized_N_varinats_greedy,Normalized_N_varinats_LP,Normalized_N_varinats_ILP_Hap]

X = np.arange(4)
width = 0.25
plt.bar(X - width/3, data[0], color = 'navy', width = 0.17,label='Greedy')
plt.bar(X + width/3, data[1], color = 'c', width = 0.17,label='LP')
plt.bar(X + width ,data[2], color = 'slateblue', width = 0.17,label='ILP Haplotype Aware') # New

plt.xticks(range(0,4), ['0%', '1%','5%', '10%'], fontsize=25)
plt.yticks(fontsize=25)

#To hide y-axis values
frame1 = plt.gca()
frame1.axes.get_yaxis().set_visible(False)

# plt.yscale("log")
# Get the y limits
# ymin, ymax = 1,8000
# ymin, ymax = 1,100000000
# Set the y limits making the maximum 5% greater
# plt.ylim(ymin, 1.05 * ymax)
# plt.ylim(ymin, ymax)

plt.xlabel(r'$\delta$', fontsize=30)
#plt.ylabel('Variants retained',fontsize=30)
plt.title(r'$\alpha =5000$',fontsize=30)
#plt.legend()
plt.savefig('[SNP]-nolog-3-chr22.pdf', bbox_inches="tight")
plt.show()

# %%
N_varinats_greedy = [7392,872]
N_varinats_LP = [7239,840 ]
N_varinats_ILP_Hap = [2435,296 ] # New

delta = [5, 10]

# %%
data = [N_varinats_greedy,N_varinats_LP,N_varinats_ILP_Hap]

X = np.arange(2)
width = 0.25
plt.bar(X - width/3, data[0], color = 'navy', width = 0.17,label='Greedy')
plt.bar(X + width/3, data[1], color = 'c', width = 0.17,label='LP')
plt.bar(X + width ,data[2], color = 'slateblue', width = 0.17,label='ILP Haplotype Aware') # New

plt.xticks(range(0,2), ['5%', '10%'], fontsize=25)
plt.yticks(fontsize=25)

#To hide y-axis values
# frame1 = plt.gca()
# frame1.axes.get_yaxis().set_visible(False)

# plt.yscale("log")
# Get the y limits
# ymin, ymax = 1,8000
# ymin, ymax = 1,100000000
# Set the y limits making the maximum 5% greater
# plt.ylim(ymin, 1.05 * ymax)
# plt.ylim(ymin, ymax)

plt.xlabel(r'$\delta$', fontsize=30)
#plt.ylabel('Variants retained',fontsize=30)
plt.title(r'$\alpha =5000$',fontsize=30)
#plt.legend()
plt.savefig('[SNP]-nolog-3-chr22_zoom.pdf', bbox_inches="tight")
plt.show()

# %% [markdown]
# # 7- Time while changing alpha for delta = 10% (SNPs)

# %%
Time_greedy = [0.0146695,0.0145767,0.011225, 0.0144438 ]
Time_LP = [4.63656, 14.8158,48.0819,95.4043]
Time_ILP_Hap = [3.8711,13.7612,39.0551,52.0915]
alpha = [150, 1000, 5000, 10000]

# %%
data = [Time_greedy,Time_LP,Time_ILP_Hap ]

X = np.arange(4)
width = 0.25
plt.bar(X - width/3, data[0], color = 'navy', width = 0.17,label='Greedy')
plt.bar(X + width/3, data[1], color = 'c', width = 0.17,label='LP')
plt.bar(X + width ,data[2], color = 'slateblue', width = 0.17,label='ILP Haplotype Aware') # New

plt.xticks(range(0,4), [150, 1000, 5000, 10000], fontsize=25)
plt.yticks(fontsize=25)


plt.yscale("log")
# Get the y limits
ymin, ymax = 0.00001,1000000
# Set the y limits making the maximum 5% greater
plt.ylim(ymin, 1.05 * ymax)

plt.xlabel(r'$\alpha$', fontsize=30)
plt.ylabel('Time (s)', fontsize=30)
plt.title(r'$\delta =10\%$', fontsize=30)
#plt.legend()
plt.savefig('[SNP]-7-chr22.pdf', bbox_inches="tight") 
plt.show()

# %% [markdown]
# # 8- Time while changing delta for alpha = 150 (SNPs)

# %%
Time_greedy = [0.0150147,0.0170012,0.0150595,0.0146695]
Time_LP = [5.26452,18.0944,10.2439,4.63656]
Time_ILP_Hap = [3.25452,12.0332,6.3456,3.8711]
delta = [0, 1, 5, 10]

# %%
data = [Time_greedy,Time_LP, Time_ILP_Hap]

X = np.arange(4)
width = 0.25
plt.bar(X - width/3, data[0], color = 'navy', width = 0.17,label='Greedy')
plt.bar(X + width/3, data[1], color = 'c', width = 0.17,label='LP')
plt.bar(X + width ,data[2], color = 'slateblue', width = 0.17,label='ILP Haplotype Aware') # New



plt.xticks(range(0,4), ['0%', '1%','5%', '10%'], fontsize=25)
plt.yticks(fontsize=25)

#To hide y-axis values
frame1 = plt.gca()
frame1.axes.get_yaxis().set_visible(False)

plt.yscale("log")
# Get the y limits
ymin, ymax = 0.00001,1000000
# Set the y limits making the maximum 5% greater
plt.ylim(ymin, 1.05 * ymax)

plt.xlabel(r'$\delta$', fontsize=30)
plt.ylabel('Time (s)', fontsize=30)
plt.title(r'$\alpha =150$', fontsize=30)
#plt.legend()
plt.savefig('[SNP]-8-chr22.pdf', bbox_inches="tight") 
plt.show()

# %% [markdown]
# # 9- Time while changing delta for alpha = 5000 (SNPs)

# %%
Time_greedy = [0.0148276,0.017024,0.0112086,0.011225]
Time_LP = [50.3784,681.8,51.3255,48.0819]
Time_ILP_Hap = [43.2812,50.765,45.3641,39.0551]
delta = [0, 1, 5, 10]

# %%
data = [Time_greedy,Time_LP,Time_ILP_Hap]

X = np.arange(4)
width = 0.25
plt.bar(X - width/3, data[0], color = 'navy', width = 0.17,label='Greedy')
plt.bar(X + width/3, data[1], color = 'c', width = 0.17,label='LP')
plt.bar(X + width ,data[2], color = 'slateblue', width = 0.17,label='ILP Haplotype Aware') # New

plt.xticks(range(0,4), ['0%', '1%','5%', '10%'], fontsize=25)
plt.yticks(fontsize=25)

#To hide y-axis values
frame1 = plt.gca()
frame1.axes.get_yaxis().set_visible(False)

plt.yscale("log")
# Get the y limits
ymin, ymax = 0.00001,1000000
# Set the y limits making the maximum 5% greater
plt.ylim(ymin, 1.05 * ymax)

plt.xlabel(r'$\delta$', fontsize=30)
plt.ylabel('Time (s)', fontsize=30)
plt.title(r'$\alpha =5000$', fontsize=30)
#plt.legend()
plt.savefig('[SNP]-9-chr22.pdf', bbox_inches="tight") 
plt.show()

# %% [markdown]
# # 10- Memory usage while changing alpha (SNPs), delta = 10%

# %%
Memory_usage_greedy = [44224/1000,44224/1000,40508/1000,44224/1000]
Memory_usage_LP = [3394612/1000,9900760/1000,40538480/1000,75852252/1000]
Memory_usage_ILP_Hap = [2884631/1000,9720822/1000,28536470/1000,65865253/1000]

alpha = [150, 1000, 5000, 10000]

# %%
data = [Memory_usage_greedy,Memory_usage_LP,Memory_usage_ILP_Hap]

X = np.arange(4)
width = 0.25
plt.bar(X - width/3, data[0], color = 'navy', width = 0.17,label='Greedy')
plt.bar(X + width/3, data[1], color = 'c', width = 0.17,label='LP')
plt.bar(X + width ,data[2], color = 'slateblue', width = 0.17,label='ILP Haplotype Aware') # New

plt.xticks(range(0,4), [150, 1000, 5000, 10000], fontsize=25)
plt.yticks(fontsize=25)

plt.yscale("log")
# Get the y limits

#ymin, ymax = 1,100000000/1000
ymin, ymax = 1,100000000
# Set the y limits making the maximum 5% greater
plt.ylim(ymin, 1.05 * ymax)

plt.xlabel(r'$\alpha$', fontsize=30)
plt.ylabel('Memory (MB)',fontsize=30)
plt.title(r'$\delta =10\%$',fontsize=30)
#plt.legend()

plt.savefig('[SNP]-10-chr22.pdf', bbox_inches="tight")
plt.show()

# %% [markdown]
# # 11- Memory usage while changing delta for alpha = 150 (SNPs)

# %%
Memory_usage_greedy = [56536/1000,45476/1000,44224/1000,44224/1000]
Memory_usage_LP = [3092728/1000,4323024/1000,3511304/1000,3394612/1000]
Memory_usage_ILP_Hap = [2892727/1000,3023629/1000,3021388/1000,2884631/1000]
delta = [0, 1, 5, 10]

# %%
data = [Memory_usage_greedy,Memory_usage_LP,Memory_usage_ILP_Hap]


X = np.arange(4)
width = 0.25
plt.bar(X - width/3, data[0], color = 'navy', width = 0.17,label='Greedy')
plt.bar(X + width/3, data[1], color = 'c', width = 0.17,label='LP')
plt.bar(X + width ,data[2], color = 'slateblue', width = 0.17,label='ILP Haplotype Aware') # New

plt.xticks(range(0,4), ['0%', '1%','5%', '10%'], fontsize=25)
plt.yticks(fontsize=25)

#To hide y-axis values
frame1 = plt.gca()
frame1.axes.get_yaxis().set_visible(False)



plt.yscale("log")
# Get the y limits
#ymin, ymax = 1,100000000/1000
ymin, ymax = 1,100000000
# Set the y limits making the maximum 5% greater
plt.ylim(ymin, 1.05 * ymax)


plt.xlabel(r'$\delta$', fontsize=30)
plt.ylabel('Memory (MB)',fontsize=30)
plt.title(r'$\alpha =150$',fontsize=30)
#plt.legend()
plt.savefig('[SNP]-11-chr22.pdf', bbox_inches="tight")
plt.show()

# %% [markdown]
# # 12- Memory usage while changing delta for alpha = 5000 (SNPs)

# %%
Memory_usage_greedy = [56536/1000,45808/1000,45808/1000,45808/1000]
Memory_usage_LP = [43255876/1000,43255876/1000,42114744/1000,40538480/1000]
Memory_usage_ILP_Hap = [33255376/1000,32257875/1000,32013744/1000,28536470/1000]
delta = [0, 1, 5, 10]

# %%
data = [Memory_usage_greedy,Memory_usage_LP,Memory_usage_ILP_Hap]


X = np.arange(4)
width = 0.25
plt.bar(X - width/3, data[0], color = 'navy', width = 0.17,label='Greedy')
plt.bar(X + width/3, data[1], color = 'c', width = 0.17,label='LP')
plt.bar(X + width ,data[2], color = 'slateblue', width = 0.17,label='ILP Haplotype Aware') # New

plt.xticks(range(0,4), ['0%', '1%','5%', '10%'], fontsize=25)
plt.yticks(fontsize=25)


#To hide y-axis values
frame1 = plt.gca()
frame1.axes.get_yaxis().set_visible(False)

plt.yscale("log")
# Get the y limits
#ymin, ymax = 1,100000000/1000
ymin, ymax = 1,100000000
# Set the y limits making the maximum 5% greater
plt.ylim(ymin, 1.05 * ymax)


plt.xlabel(r'$\delta$', fontsize=30)
plt.ylabel('Memory (MB)',fontsize=30)
plt.title(r'$\alpha =5000$',fontsize=30)
#plt.legend()
plt.savefig('[SNP]-12-chr22.pdf', bbox_inches="tight")
plt.show()

# %% [markdown]
# # Edit distance

# %% [markdown]
# # 1- Variants retained while changing alpha (INDEL), delta = 10%

# %%
N_varinats_greedy = [2053,1556,834,628]
N_varinats_Ilp = [2053,1554,751,509]
N_varinats_Ilp_pos = [2053,1554,755,513]
alpha = [150, 1000, 5000, 10000]

# %%
data = [N_varinats_greedy,N_varinats_Ilp,N_varinats_Ilp_pos]

X = np.arange(4)
width = 0.25

# plt.bar(X - width/2, data[0], color = 'navy', width = 0.25,label='Greedy')
# plt.bar(X + width/2, data[1], color = 'c', width = 0.35,label='ILP')
# plt.bar(X + width, data[2], color = 'y', width = 0.20,label='ILP_Pos')

plt.bar(X - width/3, data[0], color = 'navy', width = 0.17,label='Greedy')
plt.bar(X + width/3, data[1], color = 'c', width = 0.17,label='ILP')
plt.bar(X + width, data[2], color = 'y', width = 0.17,label='ILP_Pos')


plt.xticks(range(0,4), [150, 1000, 5000, 10000], fontsize=25)
plt.yticks(fontsize=25)

# Get the y limits
ymin, ymax = 1,2500
# Set the y limits making the maximum 5% greater
plt.ylim(ymin, 1.05 * ymax)

plt.xlabel(r'$\alpha$', fontsize=30)
plt.ylabel('Variant retained',fontsize=30)
plt.title(r'$\delta =10\%$',fontsize=30)
#plt.legend()

plt.savefig('[INDEL]-1-chr22.pdf', bbox_inches="tight")
plt.show()

# %% [markdown]
# # 2- Variants retained while changing delta(INDEL), alpha = 150

# %%
N_varinats_greedy = [2053,2053,2053,2053]
N_varinats_ILP = [2053,2053,2053,2053]
N_varinats_ILP_pos =[2053,2053,2053,2053]
delta = [0, 1, 5, 10]

# %%
data = [N_varinats_greedy,N_varinats_ILP,N_varinats_ILP_pos]

X = np.arange(4)
width = 0.25

plt.bar(X - width/3, data[0], color = 'navy', width = 0.17,label='Greedy')
plt.bar(X + width/3, data[1], color = 'c', width = 0.17,label='ILP')
plt.bar(X + width, data[2], color = 'y', width = 0.17,label='ILP_Pos')

plt.xticks(range(0,4), ['0%', '1%','5%', '10%'], fontsize=25)
plt.yticks(fontsize=25)

#To hide y-axis values
frame1 = plt.gca()
frame1.axes.get_yaxis().set_visible(False)

#plt.yscale("log")
# Get the y limits
#ymin, ymax = 1,100000000
ymin, ymax = 1,2500
# Set the y limits making the maximum 5% greater
plt.ylim(ymin, 1.05 * ymax)


plt.xlabel(r'$\delta$', fontsize=30)
plt.ylabel('Variant retained',fontsize=30)
plt.title(r'$\alpha =150$',fontsize=30)
#plt.legend()
plt.savefig('[INDEL]-2-chr22.pdf', bbox_inches="tight")
plt.show()

# %% [markdown]
# # 3- Variants retained while changing delta(INDEL), alpha = 5000

# %%
N_varinats_greedy = [2053,2011,1191,834]
N_varinats_ILP = [2053,2011,1138,751]
N_varinats_ILP_pos =[2053,2011,1140,755]
delta = [0, 1, 5, 10]

# %%
data = [N_varinats_greedy,N_varinats_ILP,N_varinats_ILP_pos]

X = np.arange(4)
width = 0.25

plt.bar(X - width/3, data[0], color = 'navy', width = 0.17,label='Greedy')
plt.bar(X + width/3, data[1], color = 'c', width = 0.17,label='ILP')
plt.bar(X + width, data[2], color = 'y', width = 0.17,label='ILP_Pos')

plt.xticks(range(0,4), ['0%', '1%','5%', '10%'], fontsize=25)
plt.yticks(fontsize=25)

#To hide y-axis values
frame1 = plt.gca()
frame1.axes.get_yaxis().set_visible(False)

# Get the y limits
ymin, ymax = 1,2500
# Set the y limits making the maximum 5% greater
plt.ylim(ymin, 1.05 * ymax)


plt.xlabel(r'$\delta$', fontsize=30)
plt.ylabel('Variant retained',fontsize=30)
plt.title(r'$\alpha =5000$',fontsize=30)
#plt.legend()
plt.savefig('[INDEL]-3-chr22.pdf', bbox_inches="tight")
plt.show()

# %% [markdown]
# # 4- Positions retained while changing alpha (INDEL), delta = 10%

# %%
N_positions_greedy = [1993,1497,797,600]
N_positions_ILP = [1993,1495,719,485]
N_positions_ILP_pos = [1993,1495,715,480]
alpha = [150, 1000, 5000, 10000]

# %%
data = [N_positions_greedy,N_positions_ILP, N_positions_ILP_pos]

X = np.arange(4)
width = 0.25
plt.bar(X - width/3, data[0], color = 'navy', width = 0.17,label='$Greedy_i$')
plt.bar(X + width/3, data[1], color = 'c', width = 0.17,label='$ILP_i^{v}$')
plt.bar(X + width, data[2], color = 'y', width = 0.17,label='$ILP_i^{p}$')

plt.xticks(range(0,4), [150, 1000, 5000, 10000], fontsize=25)
plt.yticks(fontsize=25)

#plt.yscale("log")
# Get the y limits
ymin, ymax = 1,2500
# Set the y limits making the maximum 5% greater
plt.ylim(ymin, 1.05 * ymax)

plt.xlabel(r'$\alpha$', fontsize=30)
plt.ylabel('Variant loci retained',fontsize=30)
plt.title(r'$\delta =10\%$',fontsize=30)
#plt.legend()

plt.savefig('[INDEL]-4-chr22.pdf', bbox_inches="tight")
plt.show()
plt.show()

# %% [markdown]
# # 5- Positions retained while changing delta for alpha = 150 (INDEL)

# %%
N_positions_greedy = [1993,1993, 1993, 1993]
N_positions_ILP = [1993,1993,1993,1993]
N_positions_ILP_pos = [1993,1993,1993,1993]
alpha = [150, 1000, 5000, 10000]

# %%
data = [N_positions_greedy,N_positions_ILP, N_positions_ILP_pos]

X = np.arange(4)
width = 0.25

plt.bar(X - width/3, data[0], color = 'navy', width = 0.17,label='$Greedy_i$')
plt.bar(X + width/3, data[1], color = 'c', width = 0.17,label='$ILP_i^{v}$')
plt.bar(X + width, data[2], color = 'y', width = 0.17,label='$ILP_i^{p}$')
plt.xticks(range(0,4), ['0%', '1%','5%', '10%'], fontsize=25)
plt.yticks(fontsize=25)

#To hide y-axis values
frame1 = plt.gca()
frame1.axes.get_yaxis().set_visible(False)


#plt.yscale("log")
# Get the y limits
ymin, ymax = 1,2500
# Set the y limits making the maximum 5% greater
plt.ylim(ymin, 1.05 * ymax)

plt.xlabel(r'$\delta$', fontsize=30)
#plt.ylabel('Variant loci retained',fontsize=30)
plt.title(r'$\alpha =150$',fontsize=30)
#plt.legend()

plt.savefig('[INDEL]-5-chr22.pdf', bbox_inches="tight")
plt.show()

# %% [markdown]
# # 6- Positions retained while changing delta for alpha = 5000 (INDEL)

# %%
N_positions_greedy = [1993, 1951, 1139,797]
N_positions_ILP = [1993,1951,1090,719]
N_positions_ILP_pos = [1993, 1951, 1087,715]
alpha = [150, 1000, 5000, 10000]

# %%
data = [N_positions_greedy,N_positions_ILP, N_positions_ILP_pos]

X = np.arange(4)
width = 0.25

plt.bar(X - width/3, data[0], color = 'navy', width = 0.17,label='$Greedy_i$')
plt.bar(X + width/3, data[1], color = 'c', width = 0.17,label='$ILP_i^{v}$')
plt.bar(X + width, data[2], color = 'y', width = 0.17,label='$ILP_i^{p}$')
plt.xticks(range(0,4), ['0%', '1%','5%', '10%'], fontsize=25)
plt.yticks(fontsize=25)

#To hide y-axis values
frame1 = plt.gca()
frame1.axes.get_yaxis().set_visible(False)


#plt.yscale("log")
# Get the y limits
ymin, ymax = 1,2500
# Set the y limits making the maximum 5% greater
plt.ylim(ymin, 1.05 * ymax)

plt.xlabel(r'$\delta$', fontsize=30)
#plt.ylabel('Variant loci retained',fontsize=30)
plt.title(r'$\alpha =5000$',fontsize=30)
#plt.legend()

plt.savefig('[INDEL]-6-chr22.pdf', bbox_inches="tight")
plt.show()

# %% [markdown]
# # 7- Time while changing alpha for delta = 10% (INDEL)

# %%
Time_greedy = [1.17414,5.4104,24.8308,72.7106]
Time_ILP = [2.81922,2.81922,25.0944,72.9213]
Time_ILP_pos = [1.1722,5.48746,24.9677,72.8757]
alpha = [150, 1000, 5000, 10000]

# %%
data = [Time_greedy,Time_ILP,Time_ILP_pos]

X = np.arange(4)
width = 0.25
plt.bar(X - width/3, data[0], color = 'navy', width = 0.17,label='Greedy')
plt.bar(X + width/3, data[1], color = 'c', width = 0.17,label='ILP')
plt.bar(X + width, data[2], color = 'y', width = 0.17,label='ILP_Pos')

plt.xticks(range(0,4), [150, 1000, 5000, 10000], fontsize=25)
plt.yticks(fontsize=25)

# Get the y limits
ymin, ymax = 0.0001,100
# Set the y limits making the maximum 5% greater
plt.ylim(ymin, 1.05 * ymax)

plt.xlabel(r'$\alpha$', fontsize=30)
plt.ylabel('Time (s)', fontsize=30)
plt.title(r'$\delta =10\%$', fontsize=30)
#plt.legend()
plt.savefig('[INDEL]-7-chr22.pdf', bbox_inches="tight") 
plt.show()

# %% [markdown]
# # 8- Time while changing delta for alpha = 150 (INDEL)

# %%
Time_greedy = [1.36184,1.36236,1.15335,1.17414]
Time_ILP = [3.30676,1.4288,1.36845,2.81922]
Time_ILP_pos = [1.43052,1.42771,1.16928,1.1722]
alpha = [150, 1000, 5000, 10000]

# %%
data = [Time_greedy,Time_ILP,Time_ILP_pos]

X = np.arange(4)
width = 0.25
plt.bar(X - width/3, data[0], color = 'navy', width = 0.17,label='Greedy')
plt.bar(X + width/3, data[1], color = 'c', width = 0.17,label='ILP')
plt.bar(X + width, data[2], color = 'y', width = 0.17,label='ILP_Pos')

plt.xticks(range(0,4), [150, 1000, 5000, 10000], fontsize=25)
plt.yticks(fontsize=25)

#To hide y-axis values
frame1 = plt.gca()
frame1.axes.get_yaxis().set_visible(False)


# Get the y limits
ymin, ymax = 0.0001,100
# Set the y limits making the maximum 5% greater
plt.ylim(ymin, 1.05 * ymax)

plt.xlabel(r'$\delta$', fontsize=30)
plt.ylabel('Time (s)', fontsize=30)
plt.title(r'$\alpha =150$', fontsize=30)
#plt.legend()
plt.savefig('[INDEL]-8-chr22.pdf', bbox_inches="tight") 
plt.show()

# %% [markdown]
# # 9- Time while changing delta for alpha = 5000 (INDEL)

# %%
Time_greedy = [24.8289,24.8302,24.828,24.8308]
Time_ILP = [26.4432,25.029,26.5512,25.0944]
Time_ILP_pos = [24.8565,24.8596,24.943,24.9677]
alpha = [150, 1000, 5000, 10000]

# %%
data = [Time_greedy,Time_ILP,Time_ILP_pos]

X = np.arange(4)
width = 0.25
plt.bar(X - width/3, data[0], color = 'navy', width = 0.17,label='Greedy')
plt.bar(X + width/3, data[1], color = 'c', width = 0.17,label='ILP')
plt.bar(X + width, data[2], color = 'y', width = 0.17,label='ILP_Pos')

plt.xticks(range(0,4), [150, 1000, 5000, 10000], fontsize=25)
plt.yticks(fontsize=25)

#To hide y-axis values
frame1 = plt.gca()
frame1.axes.get_yaxis().set_visible(False)

# Get the y limits
ymin, ymax = 0.0001,100
# Set the y limits making the maximum 5% greater
plt.ylim(ymin, 1.05 * ymax)

plt.xlabel(r'$\delta$', fontsize=30)
plt.ylabel('Time (s)', fontsize=30)
plt.title(r'$\alpha =5000$', fontsize=30)
#plt.legend()
plt.savefig('[INDEL]-9-chr22.pdf', bbox_inches="tight") 
plt.show()

# %% [markdown]
# # 10- Memory usage while changing alpha (INDEL), delta = 10%

# %%
Memory_usage_greedy = [609120/1000,609288/1000,609232/1000,609348/1000]
Memory_usage_ILP = [609552/1000,609464/1000,609560/1000,609612/1000]
Memory_usage_ILP_pos = [610160/1000,610104/1000,609560/1000,609676/1000]
alpha = [150, 1000, 5000, 10000]

# %%
data = [Memory_usage_greedy,Memory_usage_ILP,Memory_usage_ILP_pos]

X = np.arange(4)
width = 0.25
plt.bar(X - width/3, data[0], color = 'navy', width = 0.17,label='Greedy')
plt.bar(X + width/3, data[1], color = 'c', width = 0.17,label='ILP')
plt.bar(X + width, data[2], color = 'y', width = 0.17,label='ILP_Pos')
        
plt.xticks(range(0,4), [150, 1000, 5000, 10000], fontsize=25)
plt.yticks(fontsize=25)


# Get the y limits
ymin, ymax = 1,1000
# Set the y limits making the maximum 5% greater
plt.ylim(ymin, 1.05 * ymax)

plt.xlabel(r'$\alpha$', fontsize=30)
plt.ylabel('Memory (MB)',fontsize=30)
plt.title(r'$\delta =10\%$',fontsize=30)
#plt.legend()

plt.savefig('[INDEL]-10-chr22.pdf', bbox_inches="tight")
plt.show()

# %% [markdown]
# # 11- Memory usage while changing delta for alpha = 150 (INDEL)

# %%
Memory_usage_greedy = [609268/1000,609268/1000,609272/1000,609120/1000]
Memory_usage_ILP = [610084/1000,610084/1000,610072/1000,609552/1000]
Memory_usage_ILP_pos = [610084/1000, 609520/1000, 609520/1000,610160/1000]
delta = [0, 1, 5, 10]

# %%
data = [Memory_usage_greedy,Memory_usage_ILP,Memory_usage_ILP_pos ]

X = np.arange(4)
width = 0.25
plt.bar(X - width/3, data[0], color = 'navy', width = 0.17,label='Greedy')
plt.bar(X + width/3, data[1], color = 'c', width = 0.17,label='ILP')
plt.bar(X + width, data[2], color = 'y', width = 0.17,label='ILP_Pos')

plt.xticks(range(0,4), ['0%', '1%','5%', '10%'], fontsize=25)
plt.yticks(fontsize=25)

#To hide y-axis values
frame1 = plt.gca()
frame1.axes.get_yaxis().set_visible(False)


#To hide y-axis values
frame1 = plt.gca()
frame1.axes.get_yaxis().set_visible(False)

# Get the y limits
ymin, ymax = 1,1000
# Set the y limits making the maximum 5% greater
plt.ylim(ymin, 1.05 * ymax)


plt.xlabel(r'$\delta$', fontsize=30)
plt.ylabel('Memory (MB)',fontsize=30)
plt.title(r'$\alpha =150$',fontsize=30)
#plt.legend()
plt.savefig('[INDEL]-11-chr22.pdf', bbox_inches="tight")
plt.show()

# %% [markdown]
# # 12- Memory usage while changing delta for alpha = 5000 (INDEL)

# %%
Memory_usage_greedy = [609232/1000,609232/1000,609232/1000,609232/1000]
Memory_usage_ILP = [609560/1000,609560/1000, 609560/1000,609560/1000]
Memory_usage_ILP_pos = [609560/1000,609560/1000,609560/1000,609560/1000]
delta = [0, 1, 5, 10]

# %%
data = [Memory_usage_greedy,Memory_usage_ILP,Memory_usage_ILP_pos ]

X = np.arange(4)
width = 0.25
plt.bar(X - width/3, data[0], color = 'navy', width = 0.17,label='Greedy')
plt.bar(X + width/3, data[1], color = 'c', width = 0.17,label='ILP')
plt.bar(X + width, data[2], color = 'y', width = 0.17,label='ILP_Pos')

plt.xticks(range(0,4), ['0%', '1%','5%', '10%'], fontsize=25)
plt.yticks(fontsize=25)

#To hide y-axis values
frame1 = plt.gca()
frame1.axes.get_yaxis().set_visible(False)

# Get the y limits
ymin, ymax = 1,1000
# Set the y limits making the maximum 5% greater
plt.ylim(ymin, 1.05 * ymax)


plt.xlabel(r'$\delta$', fontsize=30)
plt.ylabel('Memory (MB)',fontsize=30)
plt.title(r'$\alpha =5000$',fontsize=30)
#plt.legend()
plt.savefig('[INDEL]-12-chr22.pdf', bbox_inches="tight")
plt.show()
